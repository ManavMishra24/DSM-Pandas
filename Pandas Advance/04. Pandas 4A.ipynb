# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop('PassengerId')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df.drop('PassengerId')
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:5396, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5248 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5249 def drop(  # type: ignore[override]
#    5250     self,
#    (...)
#    5257     errors: IgnoreRaise = "raise",
#    5258 ) -> DataFrame | None:
#    5259     """
#    5260     Drop specified labels from rows or columns.
#    5261
#    (...)
#    5394             weight  1.0     0.8
#    5395     """
# -> 5396     return super().drop(
#    5397         labels=labels,
#    5398         axis=axis,
#    5399         index=index,
#    5400         columns=columns,
#    5401         level=level,
#    5402         inplace=inplace,
#    5403         errors=errors,
#    5404     )
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:6977, in Index.drop(self, labels, errors)
#    6975 if mask.any():
#    6976     if errors != "ignore":
# -> 6977         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6978     indexer = indexer[~mask]
#    6979 return self.delete(indexer)
#
# KeyError: "['PassengerId'] not found in axis"

# %%
df.drop('Survived', axis=1, inplace=True)

# %%
df
# Out:
#      Pclass                                               Name     Sex   Age  \
# 0         3                            Braund, Mr. Owen Harris    male  22.0
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2         3                             Heikkinen, Miss. Laina  female  26.0
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4         3                           Allen, Mr. William Henry    male  35.0
# ..      ...                                                ...     ...   ...
# 886       2                              Montvila, Rev. Juozas    male  27.0
# 887       1                       Graham, Miss. Margaret Edith  female  19.0
# 888       3           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889       1                              Behr, Mr. Karl Howell    male  26.0
# 890       3                                Dooley, Mr. Patrick    male  32.0
#
#      SibSp  Parch            Ticket     Fare Cabin Embarked
# 0        1      0         A/5 21171   7.2500   NaN        S
# 1        1      0          PC 17599  71.2833   C85        C
# 2        0      0  STON/O2. 3101282   7.9250   NaN        S
# 3        1      0            113803  53.1000  C123        S
# 4        0      0            373450   8.0500   NaN        S
# ..     ...    ...               ...      ...   ...      ...
# 886      0      0            211536  13.0000   NaN        S
# 887      0      0            112053  30.0000   B42        S
# 888      1      2        W./C. 6607  23.4500   NaN        S
# 889      0      0            111369  30.0000  C148        C
# 890      0      0            370376   7.7500   NaN        Q
#
# [891 rows x 10 columns]

# %%
df.drop(3)
# Out:
#      Pclass                                               Name     Sex   Age  \
# 0         3                            Braund, Mr. Owen Harris    male  22.0
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2         3                             Heikkinen, Miss. Laina  female  26.0
# 4         3                           Allen, Mr. William Henry    male  35.0
# 5         3                                   Moran, Mr. James    male   NaN
# ..      ...                                                ...     ...   ...
# 886       2                              Montvila, Rev. Juozas    male  27.0
# 887       1                       Graham, Miss. Margaret Edith  female  19.0
# 888       3           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889       1                              Behr, Mr. Karl Howell    male  26.0
# 890       3                                Dooley, Mr. Patrick    male  32.0
#
#      SibSp  Parch            Ticket     Fare Cabin Embarked
# 0        1      0         A/5 21171   7.2500   NaN        S
# 1        1      0          PC 17599  71.2833   C85        C
# 2        0      0  STON/O2. 3101282   7.9250   NaN        S
# 4        0      0            373450   8.0500   NaN        S
# 5        0      0            330877   8.4583   NaN        Q
# ..     ...    ...               ...      ...   ...      ...
# 886      0      0            211536  13.0000   NaN        S
# 887      0      0            112053  30.0000   B42        S
# 888      1      2        W./C. 6607  23.4500   NaN        S
# 889      0      0            111369  30.0000  C148        C
# 890      0      0            370376   7.7500   NaN        Q
#
# [890 rows x 10 columns]

# %%
df
# Out:
#      Pclass                                               Name     Sex   Age  \
# 0         3                            Braund, Mr. Owen Harris    male  22.0
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2         3                             Heikkinen, Miss. Laina  female  26.0
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4         3                           Allen, Mr. William Henry    male  35.0
# ..      ...                                                ...     ...   ...
# 886       2                              Montvila, Rev. Juozas    male  27.0
# 887       1                       Graham, Miss. Margaret Edith  female  19.0
# 888       3           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889       1                              Behr, Mr. Karl Howell    male  26.0
# 890       3                                Dooley, Mr. Patrick    male  32.0
#
#      SibSp  Parch            Ticket     Fare Cabin Embarked
# 0        1      0         A/5 21171   7.2500   NaN        S
# 1        1      0          PC 17599  71.2833   C85        C
# 2        0      0  STON/O2. 3101282   7.9250   NaN        S
# 3        1      0            113803  53.1000  C123        S
# 4        0      0            373450   8.0500   NaN        S
# ..     ...    ...               ...      ...   ...      ...
# 886      0      0            211536  13.0000   NaN        S
# 887      0      0            112053  30.0000   B42        S
# 888      1      2        W./C. 6607  23.4500   NaN        S
# 889      0      0            111369  30.0000  C148        C
# 890      0      0            370376   7.7500   NaN        Q
#
# [891 rows x 10 columns]

# %%
df.drop(3, inplace=True)

# %%
df
# Out:
#      Pclass                                               Name     Sex   Age  \
# 0         3                            Braund, Mr. Owen Harris    male  22.0
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2         3                             Heikkinen, Miss. Laina  female  26.0
# 4         3                           Allen, Mr. William Henry    male  35.0
# 5         3                                   Moran, Mr. James    male   NaN
# ..      ...                                                ...     ...   ...
# 886       2                              Montvila, Rev. Juozas    male  27.0
# 887       1                       Graham, Miss. Margaret Edith  female  19.0
# 888       3           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889       1                              Behr, Mr. Karl Howell    male  26.0
# 890       3                                Dooley, Mr. Patrick    male  32.0
#
#      SibSp  Parch            Ticket     Fare Cabin Embarked
# 0        1      0         A/5 21171   7.2500   NaN        S
# 1        1      0          PC 17599  71.2833   C85        C
# 2        0      0  STON/O2. 3101282   7.9250   NaN        S
# 4        0      0            373450   8.0500   NaN        S
# 5        0      0            330877   8.4583   NaN        Q
# ..     ...    ...               ...      ...   ...      ...
# 886      0      0            211536  13.0000   NaN        S
# 887      0      0            112053  30.0000   B42        S
# 888      1      2        W./C. 6607  23.4500   NaN        S
# 889      0      0            111369  30.0000  C148        C
# 890      0      0            370376   7.7500   NaN        Q
#
# [890 rows x 10 columns]

# %%
df.set_index("Name")
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Allen, Mr. William Henry                                 3    male  35.0
# Moran, Mr. James                                         3    male   NaN
# ...                                                    ...     ...   ...
# Montvila, Rev. Juozas                                    2    male  27.0
# Graham, Miss. Margaret Edith                             1  female  19.0
# Johnston, Miss. Catherine Helen "Carrie"                 3  female   NaN
# Behr, Mr. Karl Howell                                    1    male  26.0
# Dooley, Mr. Patrick                                      3    male  32.0
#
#                                                     SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                                 1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...      1      0
# Heikkinen, Miss. Laina                                  0      0
# Allen, Mr. William Henry                                0      0
# Moran, Mr. James                                        0      0
# ...                                                   ...    ...
# Montvila, Rev. Juozas                                   0      0
# Graham, Miss. Margaret Edith                            0      0
# Johnston, Miss. Catherine Helen "Carrie"                1      2
# Behr, Mr. Karl Howell                                   0      0
# Dooley, Mr. Patrick                                     0      0
#
#                                                               Ticket     Fare  \
# Name
# Braund, Mr. Owen Harris                                    A/5 21171   7.2500
# Cumings, Mrs. John Bradley (Florence Briggs Tha...          PC 17599  71.2833
# Heikkinen, Miss. Laina                              STON/O2. 3101282   7.9250
# Allen, Mr. William Henry                                      373450   8.0500
# Moran, Mr. James                                              330877   8.4583
# ...                                                              ...      ...
# Montvila, Rev. Juozas                                         211536  13.0000
# Graham, Miss. Margaret Edith                                  112053  30.0000
# Johnston, Miss. Catherine Helen "Carrie"                  W./C. 6607  23.4500
# Behr, Mr. Karl Howell                                         111369  30.0000
# Dooley, Mr. Patrick                                           370376   7.7500
#
#                                                    Cabin Embarked
# Name
# Braund, Mr. Owen Harris                              NaN        S
# Cumings, Mrs. John Bradley (Florence Briggs Tha...   C85        C
# Heikkinen, Miss. Laina                               NaN        S
# Allen, Mr. William Henry                             NaN        S
# Moran, Mr. James                                     NaN        Q
# ...                                                  ...      ...
# Montvila, Rev. Juozas                                NaN        S
# Graham, Miss. Margaret Edith                         B42        S
# Johnston, Miss. Catherine Helen "Carrie"             NaN        S
# Behr, Mr. Karl Howell                               C148        C
# Dooley, Mr. Patrick                                  NaN        Q
#
# [890 rows x 9 columns]

# %%
df
# Out:
#      Pclass                                               Name     Sex   Age  \
# 0         3                            Braund, Mr. Owen Harris    male  22.0
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2         3                             Heikkinen, Miss. Laina  female  26.0
# 4         3                           Allen, Mr. William Henry    male  35.0
# 5         3                                   Moran, Mr. James    male   NaN
# ..      ...                                                ...     ...   ...
# 886       2                              Montvila, Rev. Juozas    male  27.0
# 887       1                       Graham, Miss. Margaret Edith  female  19.0
# 888       3           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889       1                              Behr, Mr. Karl Howell    male  26.0
# 890       3                                Dooley, Mr. Patrick    male  32.0
#
#      SibSp  Parch            Ticket     Fare Cabin Embarked
# 0        1      0         A/5 21171   7.2500   NaN        S
# 1        1      0          PC 17599  71.2833   C85        C
# 2        0      0  STON/O2. 3101282   7.9250   NaN        S
# 4        0      0            373450   8.0500   NaN        S
# 5        0      0            330877   8.4583   NaN        Q
# ..     ...    ...               ...      ...   ...      ...
# 886      0      0            211536  13.0000   NaN        S
# 887      0      0            112053  30.0000   B42        S
# 888      1      2        W./C. 6607  23.4500   NaN        S
# 889      0      0            111369  30.0000  C148        C
# 890      0      0            370376   7.7500   NaN        Q
#
# [890 rows x 10 columns]

# %%
df.set_index("Name", inplace=True)

# %%
df
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Allen, Mr. William Henry                                 3    male  35.0
# Moran, Mr. James                                         3    male   NaN
# ...                                                    ...     ...   ...
# Montvila, Rev. Juozas                                    2    male  27.0
# Graham, Miss. Margaret Edith                             1  female  19.0
# Johnston, Miss. Catherine Helen "Carrie"                 3  female   NaN
# Behr, Mr. Karl Howell                                    1    male  26.0
# Dooley, Mr. Patrick                                      3    male  32.0
#
#                                                     SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                                 1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...      1      0
# Heikkinen, Miss. Laina                                  0      0
# Allen, Mr. William Henry                                0      0
# Moran, Mr. James                                        0      0
# ...                                                   ...    ...
# Montvila, Rev. Juozas                                   0      0
# Graham, Miss. Margaret Edith                            0      0
# Johnston, Miss. Catherine Helen "Carrie"                1      2
# Behr, Mr. Karl Howell                                   0      0
# Dooley, Mr. Patrick                                     0      0
#
#                                                               Ticket     Fare  \
# Name
# Braund, Mr. Owen Harris                                    A/5 21171   7.2500
# Cumings, Mrs. John Bradley (Florence Briggs Tha...          PC 17599  71.2833
# Heikkinen, Miss. Laina                              STON/O2. 3101282   7.9250
# Allen, Mr. William Henry                                      373450   8.0500
# Moran, Mr. James                                              330877   8.4583
# ...                                                              ...      ...
# Montvila, Rev. Juozas                                         211536  13.0000
# Graham, Miss. Margaret Edith                                  112053  30.0000
# Johnston, Miss. Catherine Helen "Carrie"                  W./C. 6607  23.4500
# Behr, Mr. Karl Howell                                         111369  30.0000
# Dooley, Mr. Patrick                                           370376   7.7500
#
#                                                    Cabin Embarked
# Name
# Braund, Mr. Owen Harris                              NaN        S
# Cumings, Mrs. John Bradley (Florence Briggs Tha...   C85        C
# Heikkinen, Miss. Laina                               NaN        S
# Allen, Mr. William Henry                             NaN        S
# Moran, Mr. James                                     NaN        Q
# ...                                                  ...      ...
# Montvila, Rev. Juozas                                NaN        S
# Graham, Miss. Margaret Edith                         B42        S
# Johnston, Miss. Catherine Helen "Carrie"             NaN        S
# Behr, Mr. Karl Howell                               C148        C
# Dooley, Mr. Patrick                                  NaN        Q
#
# [890 rows x 9 columns]

# %%
df.reset_index()
# Out:
#                                                   Name  Pclass     Sex   Age  \
# 0                              Braund, Mr. Owen Harris       3    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       1  female  38.0
# 2                               Heikkinen, Miss. Laina       3  female  26.0
# 3                             Allen, Mr. William Henry       3    male  35.0
# 4                                     Moran, Mr. James       3    male   NaN
# ..                                                 ...     ...     ...   ...
# 885                              Montvila, Rev. Juozas       2    male  27.0
# 886                       Graham, Miss. Margaret Edith       1  female  19.0
# 887           Johnston, Miss. Catherine Helen "Carrie"       3  female   NaN
# 888                              Behr, Mr. Karl Howell       1    male  26.0
# 889                                Dooley, Mr. Patrick       3    male  32.0
#
#      SibSp  Parch            Ticket     Fare Cabin Embarked
# 0        1      0         A/5 21171   7.2500   NaN        S
# 1        1      0          PC 17599  71.2833   C85        C
# 2        0      0  STON/O2. 3101282   7.9250   NaN        S
# 3        0      0            373450   8.0500   NaN        S
# 4        0      0            330877   8.4583   NaN        Q
# ..     ...    ...               ...      ...   ...      ...
# 885      0      0            211536  13.0000   NaN        S
# 886      0      0            112053  30.0000   B42        S
# 887      1      2        W./C. 6607  23.4500   NaN        S
# 888      0      0            111369  30.0000  C148        C
# 889      0      0            370376   7.7500   NaN        Q
#
# [890 rows x 10 columns]

# %%
d = {'key1' : [3,4,5,6,7,],
      'key2' : [5,6,7,8,9],
      'key3' : [4,5,6,7,8]
}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     3     5     4
# 1     4     6     5
# 2     5     7     6
# 3     6     8     7
# 4     7     9     8

# %%
import pandas as pd

# %%
df1 = pd.read_csv('nucc_taxonomy.csv')

# %%
df1
# Out:
#            Code                             Grouping  \
# 0    193200000X                                Group
# 1    193400000X                                Group
# 2    207K00000X  Allopathic & Osteopathic Physicians
# 3    207KA0200X  Allopathic & Osteopathic Physicians
# 4    207KI0005X  Allopathic & Osteopathic Physicians
# ..          ...                                  ...
# 860  343800000X              Transportation Services
# 861  344600000X              Transportation Services
# 862  347D00000X              Transportation Services
# 863  347E00000X              Transportation Services
# 864  342000000X              Transportation Services
#
#                       Classification                    Specialization  \
# 0                    Multi-Specialty                               NaN
# 1                   Single Specialty                               NaN
# 2               Allergy & Immunology                               NaN
# 3               Allergy & Immunology                           Allergy
# 4               Allergy & Immunology  Clinical & Laboratory Immunology
# ..                               ...                               ...
# 860  Secured Medical Transport (VAN)                               NaN
# 861                             Taxi                               NaN
# 862                            Train                               NaN
# 863            Transportation Broker                               NaN
# 864   Transportation Network Company                               NaN
#
#                                             Definition Effective Date  \
# 0    A business group of one or more individual pra...      10/1/2003
# 1    A business group of one or more individual pra...      10/1/2003
# 2    An allergist-immunologist is trained in evalua...       4/1/2003
# 3                                Definition to come...       4/1/2003
# 4                                Definition to come...       4/1/2003
# ..                                                 ...            ...
# 860  A public or privately owned transportation ser...       4/1/2002
# 861  A land commercial vehicle used for the transpo...       4/1/2002
# 862  An organization or business licensed to provid...       4/1/2002
# 863  An organization that provides transportation f...       4/1/2002
# 864  A ride-sharing company that provides prearrang...       4/1/2021
#
#     Deactivation Date Last Modified Date  \
# 0                 NaN                NaN
# 1                 NaN                NaN
# 2                 NaN           7/1/2007
# 3                 NaN                NaN
# 4                 NaN                NaN
# ..                ...                ...
# 860               NaN                NaN
# 861               NaN                NaN
# 862               NaN                NaN
# 863               NaN           1/1/2021
# 864               NaN                NaN
#
#                                                  Notes  \
# 0                                      [7/1/2003: new]
# 1                                      [7/1/2003: new]
# 2    Source: American Board of Medical Specialties,...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 860                                                NaN
# 861                                                NaN
# 862                                                NaN
# 863  Source: Section 6083 of the Deficit Reduction ...
# 864  Source:  National Uniform Claim Committee, www...
#
#                                           Display Name
# 0                                Multi-Specialty Group
# 1                               Single Specialty Group
# 2                       Allergy & Immunology Physician
# 3                                    Allergy Physician
# 4    Clinical & Laboratory Immunology (Allergy & Im...
# ..                                                 ...
# 860                    Secured Medical Transport (VAN)
# 861                                               Taxi
# 862                                              Train
# 863                              Transportation Broker
# 864                     Transportation Network Company
#
# [865 rows x 10 columns]

# %%
df1.dropna()
# Out:
# Empty DataFrame
# Columns: [Code, Grouping, Classification, Specialization, Definition, Effective Date, Deactivation Date, Last Modified Date, Notes, Display Name]
# Index: []

# %%
df1
# Out:
#            Code                             Grouping  \
# 0    193200000X                                Group
# 1    193400000X                                Group
# 2    207K00000X  Allopathic & Osteopathic Physicians
# 3    207KA0200X  Allopathic & Osteopathic Physicians
# 4    207KI0005X  Allopathic & Osteopathic Physicians
# ..          ...                                  ...
# 860  343800000X              Transportation Services
# 861  344600000X              Transportation Services
# 862  347D00000X              Transportation Services
# 863  347E00000X              Transportation Services
# 864  342000000X              Transportation Services
#
#                       Classification                    Specialization  \
# 0                    Multi-Specialty                               NaN
# 1                   Single Specialty                               NaN
# 2               Allergy & Immunology                               NaN
# 3               Allergy & Immunology                           Allergy
# 4               Allergy & Immunology  Clinical & Laboratory Immunology
# ..                               ...                               ...
# 860  Secured Medical Transport (VAN)                               NaN
# 861                             Taxi                               NaN
# 862                            Train                               NaN
# 863            Transportation Broker                               NaN
# 864   Transportation Network Company                               NaN
#
#                                             Definition Effective Date  \
# 0    A business group of one or more individual pra...      10/1/2003
# 1    A business group of one or more individual pra...      10/1/2003
# 2    An allergist-immunologist is trained in evalua...       4/1/2003
# 3                                Definition to come...       4/1/2003
# 4                                Definition to come...       4/1/2003
# ..                                                 ...            ...
# 860  A public or privately owned transportation ser...       4/1/2002
# 861  A land commercial vehicle used for the transpo...       4/1/2002
# 862  An organization or business licensed to provid...       4/1/2002
# 863  An organization that provides transportation f...       4/1/2002
# 864  A ride-sharing company that provides prearrang...       4/1/2021
#
#     Deactivation Date Last Modified Date  \
# 0                 NaN                NaN
# 1                 NaN                NaN
# 2                 NaN           7/1/2007
# 3                 NaN                NaN
# 4                 NaN                NaN
# ..                ...                ...
# 860               NaN                NaN
# 861               NaN                NaN
# 862               NaN                NaN
# 863               NaN           1/1/2021
# 864               NaN                NaN
#
#                                                  Notes  \
# 0                                      [7/1/2003: new]
# 1                                      [7/1/2003: new]
# 2    Source: American Board of Medical Specialties,...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 860                                                NaN
# 861                                                NaN
# 862                                                NaN
# 863  Source: Section 6083 of the Deficit Reduction ...
# 864  Source:  National Uniform Claim Committee, www...
#
#                                           Display Name
# 0                                Multi-Specialty Group
# 1                               Single Specialty Group
# 2                       Allergy & Immunology Physician
# 3                                    Allergy Physician
# 4    Clinical & Laboratory Immunology (Allergy & Im...
# ..                                                 ...
# 860                    Secured Medical Transport (VAN)
# 861                                               Taxi
# 862                                              Train
# 863                              Transportation Broker
# 864                     Transportation Network Company
#
# [865 rows x 10 columns]

# %%
df1.dropna(axis=1)
# Out:
#            Code                             Grouping  \
# 0    193200000X                                Group
# 1    193400000X                                Group
# 2    207K00000X  Allopathic & Osteopathic Physicians
# 3    207KA0200X  Allopathic & Osteopathic Physicians
# 4    207KI0005X  Allopathic & Osteopathic Physicians
# ..          ...                                  ...
# 860  343800000X              Transportation Services
# 861  344600000X              Transportation Services
# 862  347D00000X              Transportation Services
# 863  347E00000X              Transportation Services
# 864  342000000X              Transportation Services
#
#                       Classification Effective Date  \
# 0                    Multi-Specialty      10/1/2003
# 1                   Single Specialty      10/1/2003
# 2               Allergy & Immunology       4/1/2003
# 3               Allergy & Immunology       4/1/2003
# 4               Allergy & Immunology       4/1/2003
# ..                               ...            ...
# 860  Secured Medical Transport (VAN)       4/1/2002
# 861                             Taxi       4/1/2002
# 862                            Train       4/1/2002
# 863            Transportation Broker       4/1/2002
# 864   Transportation Network Company       4/1/2021
#
#                                           Display Name
# 0                                Multi-Specialty Group
# 1                               Single Specialty Group
# 2                       Allergy & Immunology Physician
# 3                                    Allergy Physician
# 4    Clinical & Laboratory Immunology (Allergy & Im...
# ..                                                 ...
# 860                    Secured Medical Transport (VAN)
# 861                                               Taxi
# 862                                              Train
# 863                              Transportation Broker
# 864                     Transportation Network Company
#
# [865 rows x 5 columns]

# %%
df1.fillna("ZZZ")
# Out:
#            Code                             Grouping  \
# 0    193200000X                                Group
# 1    193400000X                                Group
# 2    207K00000X  Allopathic & Osteopathic Physicians
# 3    207KA0200X  Allopathic & Osteopathic Physicians
# 4    207KI0005X  Allopathic & Osteopathic Physicians
# ..          ...                                  ...
# 860  343800000X              Transportation Services
# 861  344600000X              Transportation Services
# 862  347D00000X              Transportation Services
# 863  347E00000X              Transportation Services
# 864  342000000X              Transportation Services
#
#                       Classification                    Specialization  \
# 0                    Multi-Specialty                               ZZZ
# 1                   Single Specialty                               ZZZ
# 2               Allergy & Immunology                               ZZZ
# 3               Allergy & Immunology                           Allergy
# 4               Allergy & Immunology  Clinical & Laboratory Immunology
# ..                               ...                               ...
# 860  Secured Medical Transport (VAN)                               ZZZ
# 861                             Taxi                               ZZZ
# 862                            Train                               ZZZ
# 863            Transportation Broker                               ZZZ
# 864   Transportation Network Company                               ZZZ
#
#                                             Definition Effective Date  \
# 0    A business group of one or more individual pra...      10/1/2003
# 1    A business group of one or more individual pra...      10/1/2003
# 2    An allergist-immunologist is trained in evalua...       4/1/2003
# 3                                Definition to come...       4/1/2003
# 4                                Definition to come...       4/1/2003
# ..                                                 ...            ...
# 860  A public or privately owned transportation ser...       4/1/2002
# 861  A land commercial vehicle used for the transpo...       4/1/2002
# 862  An organization or business licensed to provid...       4/1/2002
# 863  An organization that provides transportation f...       4/1/2002
# 864  A ride-sharing company that provides prearrang...       4/1/2021
#
#     Deactivation Date Last Modified Date  \
# 0                 ZZZ                ZZZ
# 1                 ZZZ                ZZZ
# 2                 ZZZ           7/1/2007
# 3                 ZZZ                ZZZ
# 4                 ZZZ                ZZZ
# ..                ...                ...
# 860               ZZZ                ZZZ
# 861               ZZZ                ZZZ
# 862               ZZZ                ZZZ
# 863               ZZZ           1/1/2021
# 864               ZZZ                ZZZ
#
#                                                  Notes  \
# 0                                      [7/1/2003: new]
# 1                                      [7/1/2003: new]
# 2    Source: American Board of Medical Specialties,...
# 3                                                  ZZZ
# 4                                                  ZZZ
# ..                                                 ...
# 860                                                ZZZ
# 861                                                ZZZ
# 862                                                ZZZ
# 863  Source: Section 6083 of the Deficit Reduction ...
# 864  Source:  National Uniform Claim Committee, www...
#
#                                           Display Name
# 0                                Multi-Specialty Group
# 1                               Single Specialty Group
# 2                       Allergy & Immunology Physician
# 3                                    Allergy Physician
# 4    Clinical & Laboratory Immunology (Allergy & Im...
# ..                                                 ...
# 860                    Secured Medical Transport (VAN)
# 861                                               Taxi
# 862                                              Train
# 863                              Transportation Broker
# 864                     Transportation Network Company
#
# [865 rows x 10 columns]

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
g = df.groupby('Survived')

# %%
g

# %%
g.sum()
# Out:
# /tmp/ipykernel_2122/1197020669.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.sum()
#            index  PassengerId  Pclass       Age  SibSp  Parch        Fare
# Survived
# 0         244863       245412    1390  12985.50    304    181  12142.7199
# 1         151632       151974     667   8219.67    162    159  16551.2294

# %%
g.mean()
# Out:
# /tmp/ipykernel_2122/2978112660.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.mean()
#                index  PassengerId    Pclass        Age     SibSp     Parch  \
# Survived
# 0         446.016393   447.016393  2.531876  30.626179  0.553734  0.329690
# 1         443.368421   444.368421  1.950292  28.343690  0.473684  0.464912
#
#                Fare
# Survived
# 0         22.117887
# 1         48.395408

# %%
g1 = df.groupby('Pclass')

# %%
g1

# %%
g1.sum()
# Out:
# /tmp/ipykernel_2122/2725926089.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.sum()
#          index  PassengerId  Survived      Age  SibSp  Parch        Fare
# Pclass
# 1        99489        99705       136  7111.42     90     77  18177.4125
# 2        81872        82056        87  5168.83     74     70   3801.8417
# 3       215134       215625       119  8924.92    302    193   6714.6951

# %%
g1.mean()
# Out:
# /tmp/ipykernel_2122/3287460031.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.mean()
#              index  PassengerId  Survived        Age     SibSp     Parch  \
# Pclass
# 1       460.597222   461.597222  0.629630  38.233441  0.416667  0.356481
# 2       444.956522   445.956522  0.472826  29.877630  0.402174  0.380435
# 3       438.154786   439.154786  0.242363  25.140620  0.615071  0.393075
#
#              Fare
# Pclass
# 1       84.154687
# 2       20.662183
# 3       13.675550

# %%
g1.max()['Fare']
# Out:
# /tmp/ipykernel_2122/730728694.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max()['Fare']
# Pclass
# 1    512.3292
# 2     73.5000
# 3     69.5500
# Name: Fare, dtype: float64

# %%
g1.max()
# Out:
# /tmp/ipykernel_2122/130714741.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max()
#         index  PassengerId  Survived                         Name   Sex   Age  \
# Pclass
# 1         889          890         1     Young, Miss. Marie Grice  male  80.0
# 2         886          887         1    del Carlo, Mr. Sebastiano  male  70.0
# 3         890          891         1  van Melkebeke, Mr. Philemon  male  74.0
#
#         SibSp  Parch      Ticket      Fare
# Pclass
# 1           3      4   WE/P 5735  512.3292
# 2           3      3   W/C 14208   73.5000
# 3           8      6  W./C. 6609   69.5500

# %%
g1.max().T
# Out:
# /tmp/ipykernel_2122/2755232466.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max().T
# Pclass                              1                          2  \
# index                             889                        886
# PassengerId                       890                        887
# Survived                            1                          1
# Name         Young, Miss. Marie Grice  del Carlo, Mr. Sebastiano
# Sex                              male                       male
# Age                              80.0                       70.0
# SibSp                               3                          3
# Parch                               4                          3
# Ticket                      WE/P 5735                  W/C 14208
# Fare                         512.3292                       73.5
#
# Pclass                                 3
# index                                890
# PassengerId                          891
# Survived                               1
# Name         van Melkebeke, Mr. Philemon
# Sex                                 male
# Age                                 74.0
# SibSp                                  8
# Parch                                  6
# Ticket                        W./C. 6609
# Fare                               69.55

# %%
g1.max().transpose()
# Out:
# /tmp/ipykernel_2122/3907411846.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max().transpose()
# Pclass                              1                          2  \
# index                             889                        886
# PassengerId                       890                        887
# Survived                            1                          1
# Name         Young, Miss. Marie Grice  del Carlo, Mr. Sebastiano
# Sex                              male                       male
# Age                              80.0                       70.0
# SibSp                               3                          3
# Parch                               4                          3
# Ticket                      WE/P 5735                  W/C 14208
# Fare                         512.3292                       73.5
#
# Pclass                                 3
# index                                890
# PassengerId                          891
# Survived                               1
# Name         van Melkebeke, Mr. Philemon
# Sex                                 male
# Age                                 74.0
# SibSp                                  8
# Parch                                  6
# Ticket                        W./C. 6609
# Fare                               69.55

# %%
df
# Out:
#      index  PassengerId  Survived  Pclass  \
# 0        0            1         0       3
# 1        1            2         1       1
# 2        2            3         1       3
# 3        3            4         1       1
# 4        4            5         0       3
# ..     ...          ...       ...     ...
# 886    886          887         0       2
# 887    887          888         1       1
# 888    888          889         0       3
# 889    889          890         1       1
# 890    890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 13 columns]

# %%
df10 = df[['Name', 'Survived', 'Pclass']][0:5]

# %%
df11 = df[['Name', 'Survived', 'Pclass']][5:10]

# %%
df10
# Out:
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                           Allen, Mr. William Henry         0       3

# %%
df11
# Out:
#                                                 Name  Survived  Pclass
# 5                                   Moran, Mr. James         0       3
# 6                            McCarthy, Mr. Timothy J         0       1
# 7                     Palsson, Master. Gosta Leonard         0       3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 9                Nasser, Mrs. Nicholas (Adele Achem)         1       2

# %%
pd.concat([df10,df11])
# Out:
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                           Allen, Mr. William Henry         0       3
# 5                                   Moran, Mr. James         0       3
# 6                            McCarthy, Mr. Timothy J         0       1
# 7                     Palsson, Master. Gosta Leonard         0       3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 9                Nasser, Mrs. Nicholas (Adele Achem)         1       2

# %%
df12 = pd.concat([df10,df11], axis=1)

# %%
df12.fillna('mana')
# Out:
#                                                 Name Survived Pclass  \
# 0                            Braund, Mr. Owen Harris      0.0    3.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1.0    1.0
# 2                             Heikkinen, Miss. Laina      1.0    3.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1.0    1.0
# 4                           Allen, Mr. William Henry      0.0    3.0
# 5                                               mana     mana   mana
# 6                                               mana     mana   mana
# 7                                               mana     mana   mana
# 8                                               mana     mana   mana
# 9                                               mana     mana   mana
#
#                                                 Name Survived Pclass
# 0                                               mana     mana   mana
# 1                                               mana     mana   mana
# 2                                               mana     mana   mana
# 3                                               mana     mana   mana
# 4                                               mana     mana   mana
# 5                                   Moran, Mr. James      0.0    3.0
# 6                            McCarthy, Mr. Timothy J      0.0    1.0
# 7                     Palsson, Master. Gosta Leonard      0.0    3.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)      1.0    3.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)      1.0    2.0

# %%
data1 = pd.DataFrame({'key1' : [1,2,3,4,5],
                      'key2' : [4,5,6,7,8],
                      'key3' : [3,4,5,6,7]
                     })

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     3     6     5
# 3     4     7     6
# 4     5     8     7

# %%
data2 = pd.DataFrame({'key1' : [1,5,3,7,9],
                      'key4' : [8,5,2,7,3],
                      'key5' : [7,3,8,6,9]
                     })

# %%
data2
# Out:
#    key1  key4  key5
# 0     1     8     7
# 1     5     5     3
# 2     3     2     8
# 3     7     7     6
# 4     9     3     9

# %%
pd.merge(data1, data2)
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3     8     7
# 1     3     6     5     2     8
# 2     5     8     7     5     3

# %%
pd.merge(data1, data2, how = 'left')
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3   8.0   7.0
# 1     2     5     4   NaN   NaN
# 2     3     6     5   2.0   8.0
# 3     4     7     6   NaN   NaN
# 4     5     8     7   5.0   3.0

# %%
pd.merge(data1, data2, how = 'right')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0     8     7
# 1     5   8.0   7.0     5     3
# 2     3   6.0   5.0     2     8
# 3     7   NaN   NaN     7     6
# 4     9   NaN   NaN     3     9

# %%
pd.merge(data1, data2, how = 'outer')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0   8.0   7.0
# 1     2   5.0   4.0   NaN   NaN
# 2     3   6.0   5.0   2.0   8.0
# 3     4   7.0   6.0   NaN   NaN
# 4     5   8.0   7.0   5.0   3.0
# 5     7   NaN   NaN   7.0   6.0
# 6     9   NaN   NaN   3.0   9.0

# %%
pd.merge(data1, data2, how = 'cross')
# Out:
#     key1_x  key2  key3  key1_y  key4  key5
# 0        1     4     3       1     8     7
# 1        1     4     3       5     5     3
# 2        1     4     3       3     2     8
# 3        1     4     3       7     7     6
# 4        1     4     3       9     3     9
# 5        2     5     4       1     8     7
# 6        2     5     4       5     5     3
# 7        2     5     4       3     2     8
# 8        2     5     4       7     7     6
# 9        2     5     4       9     3     9
# 10       3     6     5       1     8     7
# 11       3     6     5       5     5     3
# 12       3     6     5       3     2     8
# 13       3     6     5       7     7     6
# 14       3     6     5       9     3     9
# 15       4     7     6       1     8     7
# 16       4     7     6       5     5     3
# 17       4     7     6       3     2     8
# 18       4     7     6       7     7     6
# 19       4     7     6       9     3     9
# 20       5     8     7       1     8     7
# 21       5     8     7       5     5     3
# 22       5     8     7       3     2     8
# 23       5     8     7       7     7     6
# 24       5     8     7       9     3     9

# %%
pd.merge(data1, data2, how = 'outer', on = 'key1')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0   8.0   7.0
# 1     2   5.0   4.0   NaN   NaN
# 2     3   6.0   5.0   2.0   8.0
# 3     4   7.0   6.0   NaN   NaN
# 4     5   8.0   7.0   5.0   3.0
# 5     7   NaN   NaN   7.0   6.0
# 6     9   NaN   NaN   3.0   9.0

# %%
data1 = pd.DataFrame({'key1' : [1,2,3,4,5],
                      'key2' : [4,5,6,7,8],
                      'key3' : [3,4,5,6,7]},
                    index = ['a', 'b', 'c', 'd', 'e'])

# %%
data1
# Out:
#    key1  key2  key3
# a     1     4     3
# b     2     5     4
# c     3     6     5
# d     4     7     6
# e     5     8     7

# %%
data2 = pd.DataFrame({'key11' : [1,2,3,4,5],
                      'key22' : [4,5,6,7,8],
                      'key33' : [3,4,5,6,7]},
                    index = ['a', 'b', 'h', 'i', 'j'])

# %%
data2
# Out:
#    key11  key22  key33
# a      1      4      3
# b      2      5      4
# h      3      6      5
# i      4      7      6
# j      5      8      7

# %%
data1.join(data2)
# Out:
#    key1  key2  key3  key11  key22  key33
# a     1     4     3    1.0    4.0    3.0
# b     2     5     4    2.0    5.0    4.0
# c     3     6     5    NaN    NaN    NaN
# d     4     7     6    NaN    NaN    NaN
# e     5     8     7    NaN    NaN    NaN

# %%
data1.join(data2, how = 'right')
# Out:
#    key1  key2  key3  key11  key22  key33
# a   1.0   4.0   3.0      1      4      3
# b   2.0   5.0   4.0      2      5      4
# h   NaN   NaN   NaN      3      6      5
# i   NaN   NaN   NaN      4      7      6
# j   NaN   NaN   NaN      5      8      7

# %%
data1.join(data2, how = 'inner')
# Out:
#    key1  key2  key3  key11  key22  key33
# a     1     4     3      1      4      3
# b     2     5     4      2      5      4

# %%
data1.join(data2, how = 'outer')
# Out:
#    key1  key2  key3  key11  key22  key33
# a   1.0   4.0   3.0    1.0    4.0    3.0
# b   2.0   5.0   4.0    2.0    5.0    4.0
# c   3.0   6.0   5.0    NaN    NaN    NaN
# d   4.0   7.0   6.0    NaN    NaN    NaN
# e   5.0   8.0   7.0    NaN    NaN    NaN
# h   NaN   NaN   NaN    3.0    6.0    5.0
# i   NaN   NaN   NaN    4.0    7.0    6.0
# j   NaN   NaN   NaN    5.0    8.0    7.0

# %%
data1.join(data2, how = 'cross')
# Out:
#     key1  key2  key3  key11  key22  key33
# 0      1     4     3      1      4      3
# 1      1     4     3      2      5      4
# 2      1     4     3      3      6      5
# 3      1     4     3      4      7      6
# 4      1     4     3      5      8      7
# 5      2     5     4      1      4      3
# 6      2     5     4      2      5      4
# 7      2     5     4      3      6      5
# 8      2     5     4      4      7      6
# 9      2     5     4      5      8      7
# 10     3     6     5      1      4      3
# 11     3     6     5      2      5      4
# 12     3     6     5      3      6      5
# 13     3     6     5      4      7      6
# 14     3     6     5      5      8      7
# 15     4     7     6      1      4      3
# 16     4     7     6      2      5      4
# 17     4     7     6      3      6      5
# 18     4     7     6      4      7      6
# 19     4     7     6      5      8      7
# 20     5     8     7      1      4      3
# 21     5     8     7      2      5      4
# 22     5     8     7      3      6      5
# 23     5     8     7      4      7      6
# 24     5     8     7      5      8      7

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df['Fare_INR'] = df['Fare'].apply(lambda x : x*80)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Fare_INR
# 0      0         A/5 21171   7.2500   NaN        S   580.000
# 1      0          PC 17599  71.2833   C85        C  5702.664
# 2      0  STON/O2. 3101282   7.9250   NaN        S   634.000
# 3      0            113803  53.1000  C123        S  4248.000
# 4      0            373450   8.0500   NaN        S   644.000

# %%
def euro_inr(x):
    return x*82

df['Fare_INR'] = df['Fare'].apply(euro_inr)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked   Fare_INR
# 0        0         A/5 21171   7.2500   NaN        S   594.5000
# 1        0          PC 17599  71.2833   C85        C  5845.2306
# 2        0  STON/O2. 3101282   7.9250   NaN        S   649.8500
# 3        0            113803  53.1000  C123        S  4354.2000
# 4        0            373450   8.0500   NaN        S   660.1000
# ..     ...               ...      ...   ...      ...        ...
# 886      0            211536  13.0000   NaN        S  1066.0000
# 887      0            112053  30.0000   B42        S  2460.0000
# 888      2        W./C. 6607  23.4500   NaN        S  1922.9000
# 889      0            111369  30.0000  C148        C  2460.0000
# 890      0            370376   7.7500   NaN        Q   635.5000
#
# [891 rows x 13 columns]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked   Fare_INR
# 0      0         A/5 21171   7.2500   NaN        S   594.5000
# 1      0          PC 17599  71.2833   C85        C  5845.2306
# 2      0  STON/O2. 3101282   7.9250   NaN        S   649.8500
# 3      0            113803  53.1000  C123        S  4354.2000
# 4      0            373450   8.0500   NaN        S   660.1000

# %%
df['Name_len'] = df['Name'].apply(len)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked   Fare_INR  Name_len
# 0      0         A/5 21171   7.2500   NaN        S   594.5000        23
# 1      0          PC 17599  71.2833   C85        C  5845.2306        51
# 2      0  STON/O2. 3101282   7.9250   NaN        S   649.8500        22
# 3      0            113803  53.1000  C123        S  4354.2000        44
# 4      0            373450   8.0500   NaN        S   660.1000        24

# %%
def cat_fare(x):
    if x<10:
        return "cheap"
    elif x>=10 and x<20:
        return "mid-range"
    else:
        return "high"

# %%
df['cat_fare'] = df['Fare'].apply(cat_fare)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked   Fare_INR  Name_len  \
# 0      0         A/5 21171   7.2500   NaN        S   594.5000        23
# 1      0          PC 17599  71.2833   C85        C  5845.2306        51
# 2      0  STON/O2. 3101282   7.9250   NaN        S   649.8500        22
# 3      0            113803  53.1000  C123        S  4354.2000        44
# 4      0            373450   8.0500   NaN        S   660.1000        24
#
#   cat_fare
# 0    cheap
# 1     high
# 2    cheap
# 3     high
# 4    cheap
